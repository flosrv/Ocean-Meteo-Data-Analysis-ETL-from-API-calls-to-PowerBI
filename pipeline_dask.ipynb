# %%
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 1
from imports import *
from functions import *

# %%
import dask.dataframe as dd

# get all stations and some metadata as a Dask DataFrame
stations_df = api.stations()
# parse the response as a Dask DataFrame
stations_df = dd.from_pandas(api.stations(as_df=True), npartitions=4)

print(len(stations_df))
# Out:
# 146

# %% [markdown]
# # Filter Buoys by Remarks

# %%
import dask.dataframe as dd
import numpy as np

access_error_url_list = []

# Liste de mots à rechercher dans la colonne "Remark"
blacklist = ["Failure", "ceased", "failed", "recovered", "stopped", 'adrift']
stations_id_set = set()

print(f'Avant Filtre: {stations_df.shape[0].compute()}')  # Utiliser .compute() pour évaluer l'expression et obtenir le nombre réel

# Liste pour collecter les indices à supprimer
indices_a_supprimer = []

# Fonction qui sera appliquée à chaque partition
def filter_rows(df):
    indices_a_supprimer_partition = []
    for idx, row in df.iterrows():
        station_id = row["Station"]
        station_Location = row["Hull No./Config and Location"]  # Extraire la valeur de la cellule pour chaque ligne

        # Vérifier si station_Location n'est pas NaN
        if isinstance(station_Location, str) and ")" in station_Location:
            station_name = station_Location.split(')')[1].rstrip(" )")  # On enlève l'espace et la parenthèse en fin de chaîne
        else:
            station_name = station_Location.strip() if isinstance(station_Location, str) else ""  # Si pas de ")", on garde toute la chaîne

        station_name = station_name.rstrip(" )").replace("(", "").replace(")", "").strip()

        # Nettoyage final pour enlever toute parenthèse ou espace en fin de nom
        station_name = station_name.rstrip(" )")

        # Vérifier si "Remark" n'est pas NaN et si un des éléments de blacklist est dans "Remark"
        if isinstance(row["Remark"], str) and any(blacklist_word.lower() in row["Remark"].lower() for blacklist_word in blacklist):
            # Ajouter l'index à la liste
            indices_a_supprimer_partition.append(idx)
            url = get_buoy_url(station_id)
            access_error_url_list.append(url)
    
    # Retourner les lignes restantes après suppression
    return df.loc[~df.index.isin(indices_a_supprimer_partition)]

# Définir un meta (structure de données pour Dask)
meta = stations_df.head(0)  # Cela va retourner la structure des colonnes sans les données.

# Appliquer le filtre sur toutes les partitions
stations_df = stations_df.map_partitions(filter_rows, meta=meta)

# Utiliser .compute() pour obtenir la taille réelle après le filtrage
print(f'Après Filtre: {stations_df.shape[0].compute()}')  # Utiliser .compute() ici aussi pour évaluer le résultat
# Out:
# Avant Filtre: 146
# Après Filtre: 43

# %% [markdown]
# # Build Buoys_datas Dict

# %%
# Dictionnaire pour stocker les DataFrames, clé : ID de la bouée, valeur : DataFrame
buoy_datas = {}
buoy_list = []

# Parcours de chaque bouée dans stations_df
for index, row in stations_df.iterrows():
    buoy_id = row['Station']
    metadata = get_station_metadata(buoy_id)

    # ✅ Récupérer les données sous forme de dictionnaire
    buoy_info = parse_buoy_json(metadata)

    # ✅ Stocker directement les données dans buoy_datas
    buoy_datas[buoy_id] = buoy_info
    buoy_list.append(buoy_id)

# Affichage du nombre de bouées réussies et échouées
print(f"Nombre de bouées traitées : {len(buoy_datas)}\n")

# Afficher le contenu de buoy_datas

first_key = next(iter(buoy_datas))
first_key
buoy_datas[first_key]
# Out:
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : southwest pass, la
# 🆔 Station ID : BURL1
# ✅ Coordonnées extraites : Latitude = 28.91N, Longitude = 89.43W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 13.4
# 💨 Anemometer Height : 38
# 🌤️ Air Temp Height : 13.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=BURL1
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : grays reef
# 🆔 Station ID : 41008
# ✅ Coordonnées extraites : Latitude = 31.40N, Longitude = 80.87W
# 🌊 Water Depth : 16 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=41008
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : five fingers, ak
# 🆔 Station ID : FFIA2
# ✅ Coordonnées extraites : Latitude = 57.27N, Longitude = 133.63W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 21.3
# 💨 Anemometer Height : 22
# 🌤️ Air Temp Height : 4.3
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=FFIA2
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : ne st martin
# 🆔 Station ID : 41044
# ✅ Coordonnées extraites : Latitude = 21.58N, Longitude = 58.63W
# 🌊 Water Depth : 5419 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=41044
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : keaton beach, fl
# 🆔 Station ID : KTNF1
# ✅ Coordonnées extraites : Latitude = 29.82N, Longitude = 83.59W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 3
# 💨 Anemometer Height : 10
# 🌤️ Air Temp Height : 9.1
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=KTNF1
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : south bermuda
# 🆔 Station ID : 41049
# ✅ Coordonnées extraites : Latitude = 27.50N, Longitude = 62.27W
# 🌊 Water Depth : 5480 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=41049
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : mid gulf
# 🆔 Station ID : 42001
# ✅ Coordonnées extraites : Latitude = 25.93N, Longitude = 89.66W
# 🌊 Water Depth : 3200 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42001
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : long key, fl
# 🆔 Station ID : LONF1
# ✅ Coordonnées extraites : Latitude = 24.84N, Longitude = 80.86W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 5.03
# 💨 Anemometer Height : 6.34
# 🌤️ Air Temp Height : 6.1
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=LONF1
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : mt. desert rock, me
# 🆔 Station ID : MDRM1
# ✅ Coordonnées extraites : Latitude = 43.97N, Longitude = 68.13W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 16.5
# 💨 Anemometer Height : 22.6
# 🌤️ Air Temp Height : 15.2
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=MDRM1
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : west gulf
# 🆔 Station ID : 42002
# ✅ Coordonnées extraites : Latitude = 25.95N, Longitude = 93.78W
# 🌊 Water Depth : 3208 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42002
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : middle rock light, ak
# 🆔 Station ID : MRKA2
# ✅ Coordonnées extraites : Latitude = 61.08N, Longitude = 146.66W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 10.9
# 💨 Anemometer Height : 15.9
# 🌤️ Air Temp Height : 15.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=MRKA2
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : orange beach
# 🆔 Station ID : 42012
# ✅ Coordonnées extraites : Latitude = 30.06N, Longitude = 87.55W
# 🌊 Water Depth : 23.5 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42012
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : potato point, ak
# 🆔 Station ID : POTA2
# ✅ Coordonnées extraites : Latitude = 61.06N, Longitude = 146.70W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 8.5
# 💨 Anemometer Height : 10
# 🌤️ Air Temp Height : 9.1
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=POTA2
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : west tampa
# 🆔 Station ID : 42036
# ✅ Coordonnées extraites : Latitude = 28.50N, Longitude = 84.50W
# 🌊 Water Depth : 53.3 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42036
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : sand key, fl
# 🆔 Station ID : SANF1
# ✅ Coordonnées extraites : Latitude = 24.46N, Longitude = 81.88W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 13.6
# 💨 Anemometer Height : 14.8
# 🌤️ Air Temp Height : 14.6
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=SANF1
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : yucatan basin
# 🆔 Station ID : 42056
# ✅ Coordonnées extraites : Latitude = 19.82N, Longitude = 84.98W
# 🌊 Water Depth : 4578 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42056
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : south bass island, oh
# 🆔 Station ID : SBIO1
# ✅ Coordonnées extraites : Latitude = 41.63N, Longitude = 82.84W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 178.4
# 💨 Anemometer Height : 24.3
# 🌤️ Air Temp Height : 23.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=SBIO1
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : central caribbean
# 🆔 Station ID : 42058
# ✅ Coordonnées extraites : Latitude = 14.51N, Longitude = 75.15W
# 🌊 Water Depth : 4136 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42058
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : sombrero key, fl
# 🆔 Station ID : SMKF1
# ✅ Coordonnées extraites : Latitude = 24.63N, Longitude = 81.11W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 6
# 💨 Anemometer Height : 7.2
# 🌤️ Air Temp Height : 7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=SMKF1
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : portland
# 🆔 Station ID : 44007
# ✅ Coordonnées extraites : Latitude = 43.52N, Longitude = 70.14W
# 🌊 Water Depth : 49 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44007
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : nantucket sound
# 🆔 Station ID : 44020
# ✅ Coordonnées extraites : Latitude = 41.50N, Longitude = 70.28W
# 🌊 Water Depth : 16.5 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44020
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : long island
# 🆔 Station ID : 44025
# ✅ Coordonnées extraites : Latitude = 40.26N, Longitude = 73.17W
# 🌊 Water Depth : 40.2 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44025
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : jonesport, me
# 🆔 Station ID : 44027
# ✅ Coordonnées extraites : Latitude = 44.28N, Longitude = 67.30W
# 🌊 Water Depth : 188 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44027
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : new york harbor entrance
# 🆔 Station ID : 44065
# ✅ Coordonnées extraites : Latitude = 40.37N, Longitude = 73.70W
# 🌊 Water Depth : 26 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44065
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : western gulf of alaska
# 🆔 Station ID : 46001
# ✅ Coordonnées extraites : Latitude = 56.30N, Longitude = 148.03W
# 🌊 Water Depth : 4123 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46001
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : southeast papa
# 🆔 Station ID : 46006
# ✅ Coordonnées extraites : Latitude = 40.76N, Longitude = 137.38W
# 🌊 Water Depth : 4347 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46006
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : pt arena
# 🆔 Station ID : 46014
# ✅ Coordonnées extraites : Latitude = 39.23N, Longitude = 123.98W
# 🌊 Water Depth : 335 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46014
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : eel river
# 🆔 Station ID : 46022
# ✅ Coordonnées extraites : Latitude = 40.72N, Longitude = 124.54W
# 🌊 Water Depth : 456 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 3.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46022
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : santa monica basin
# 🆔 Station ID : 46025
# ✅ Coordonnées extraites : Latitude = 33.76N, Longitude = 119.05W
# 🌊 Water Depth : 890 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46025
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : st georges
# 🆔 Station ID : 46027
# ✅ Coordonnées extraites : Latitude = 41.84N, Longitude = 124.38W
# 🌊 Water Depth : 60 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46027
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : columbia river bar
# 🆔 Station ID : 46029
# ✅ Coordonnées extraites : Latitude = 46.16N, Longitude = 124.49W
# 🌊 Water Depth : 131 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46029
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : east santa barbara
# 🆔 Station ID : 46053
# ✅ Coordonnées extraites : Latitude = 34.24N, Longitude = 119.84W
# 🌊 Water Depth : 405 m
# 🌡️ Sea Temp Depth : 1.1
# 🌬️ Barometer Elevation (m): 1.8
# 💨 Anemometer Height : 3.2
# 🌤️ Air Temp Height : 2.8
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46053
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : south santa rosa
# 🆔 Station ID : 46069
# ✅ Coordonnées extraites : Latitude = 33.68N, Longitude = 120.21W
# 🌊 Water Depth : 977.8 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46069
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : western aleutians
# 🆔 Station ID : 46071
# ✅ Coordonnées extraites : Latitude = 51.04N, Longitude = 179.76E
# 🌊 Water Depth : 3967 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46071
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : central aleutians 230 nm sw dutch harbor
# 🆔 Station ID : 46072
# ✅ Coordonnées extraites : Latitude = 51.65N, Longitude = 172.15W
# 🌊 Water Depth : 3589 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46072
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : albatross bank
# 🆔 Station ID : 46078
# ✅ Coordonnées extraites : Latitude = 55.56N, Longitude = 152.60W
# 🌊 Water Depth : 5361 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46078
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : cape edgecumbe
# 🆔 Station ID : 46084
# ✅ Coordonnées extraites : Latitude = 56.61N, Longitude = 136.04W
# 🌊 Water Depth : 1149 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46084
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : san clemente basin
# 🆔 Station ID : 46086
# ✅ Coordonnées extraites : Latitude = 32.50N, Longitude = 118.05W
# 🌊 Water Depth : 1844.7 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46086
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : neah bay
# 🆔 Station ID : 46087
# ✅ Coordonnées extraites : Latitude = 48.49N, Longitude = 124.73W
# 🌊 Water Depth : 262.4 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46087
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : new dungeness
# 🆔 Station ID : 46088
# ✅ Coordonnées extraites : Latitude = 48.33N, Longitude = 123.18W
# 🌊 Water Depth : 115.5 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46088
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : northern hawaii one
# 🆔 Station ID : 51000
# ✅ Coordonnées extraites : Latitude = 23.53N, Longitude = 153.79W
# 🌊 Water Depth : 4762 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=51000
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : northwestern hawaii one
# 🆔 Station ID : 51001
# ✅ Coordonnées extraites : Latitude = 24.48N, Longitude = 162.03W
# 🌊 Water Depth : 4895 m
# 🌡️ Sea Temp Depth : 1.1
# 🌬️ Barometer Elevation (m): 1.8
# 💨 Anemometer Height : 3.2
# 🌤️ Air Temp Height : 2.8
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=51001
# ✅ Parsing terminé !
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : southwest hawaii
# 🆔 Station ID : 51002
# ✅ Coordonnées extraites : Latitude = 17.07N, Longitude = 157.75W
# 🌊 Water Depth : 4979 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=51002
# ✅ Parsing terminé !
#
# Nombre de bouées traitées : 43
# {'station_zone': 'southwest pass, la',
#  'lat_buoy': '28.91N',
#  'lon_buoy': '89.43W',
#  'Water_depth': 'N/A',
#  'sea_temp_depth': None,
#  'Barometer_elevation': '13.4',
#  'Anemometer_height': '38',
#  'Air_temp_height': '13.7',
#  'url': 'https://www.ndbc.noaa.gov/station_page.php?station=BURL1'}

# %% [markdown]
# # Marine and Meteo Data Collection Process

# %%
# 🚀 Démarrage du processus
print("\n🚀 Démarrage du processus de collecte des données...\n")

# Initialisation des compteurs
marine_data_collected_successfully = marine_data_collected_failed = 0
meteo_data_collected_successfully = meteo_data_collected_failed = 0

success = False
total_stations = stations_df.shape[0]
count = 0

# 🔄 Parcours des bouées / stations
for idx, row in stations_df.iterrows():
    buoy_id = row["Station"]

    ######### 🌊 MARINE DATA #########
    try:
        df_marine = NDBC.realtime_observations(buoy_id)
        if df_marine is None or df_marine.empty:
            marine_data_collected_failed += 1
            continue

        marine_data_collected_successfully += 1
    except Exception as e:
        print(f"⚠️ Erreur collecte marine {buoy_id}: {e}")
        marine_data_collected_failed += 1
        continue

    # Ajout des métadonnées
    try:
        buoy_info = buoy_datas.get(buoy_id, {})
        Lat, Lon = buoy_info.get('lat_buoy'), buoy_info.get('lon_buoy')
        if Lat is None or Lon is None:
            raise ValueError(f"Données manquantes pour {buoy_id}")

        df_marine['Lat'] = Lat
        df_marine['Lon'] = Lon
        df_marine['Water_depth'] = buoy_info.get('Water_depth', None)
        df_marine.columns = ['Datetime' if 'date' in col.lower() or 'time' in col.lower() else col for col in df_marine.columns]
        df_marine['Datetime'] = df_marine['Datetime'].dt.tz_localize(None)

        buoy_datas[buoy_id]["Marine"] = df_marine

        station_zone = safe_get(parse_buoy_json(get_station_metadata(buoy_id)), "station_zone")
        Bronze_Marine_table_Name = f"br_{buoy_id}_marine_{station_zone}".replace('.', '_').replace('-', '_').replace(' ', '_').lower()

    except Exception as e:
        print(f"⚠️ Erreur métadonnées marine {buoy_id}: {e}")
        marine_data_collected_failed += 1
        continue

    ######### ⛅ METEO DATA #########
    try:
        df_meteo = meteo_api_request([Lat, Lon])
        if df_meteo is None or df_meteo.empty:
            meteo_data_collected_failed += 1
            continue
        
        rename_columns(df_meteo, {'date':'Datetime'})
        df_meteo.columns = ['Datetime' if 'date' in col.lower() or 'time' in col.lower() else col for col in df_meteo.columns]
        df_meteo['Datetime'] = df_meteo['Datetime'].dt.tz_localize(None)
    
        buoy_datas[buoy_id]["Meteo"] = df_meteo
        meteo_data_collected_successfully += 1
    except Exception as e:
        print(f"⚠️ Erreur collecte météo {buoy_id}: {e}")
        meteo_data_collected_failed += 1
        continue

# Retirer les bouées avec des DataFrames vides ou None
buoy_datas = {buoy_id: data for buoy_id, data in buoy_datas.items() 
              if "Marine" in data and data["Marine"] is not None and not data["Marine"].empty
              and "Meteo" in data and data["Meteo"] is not None and not data["Meteo"].empty}

# 🔚 Résumé final

print("\n📝 Résumé final :")
print(f"🌊 Marine - Collecte ✅ {marine_data_collected_successfully} ❌ {marine_data_collected_failed}")
print(f"⛅ Météo - Collecte ✅ {meteo_data_collected_successfully} ❌ {meteo_data_collected_failed}")

# Afficher la longueur du dictionnaire (nombre de bouées avec des données valides)
print(f"\n📊 Nombre de bouées avec des données valides : {len(buoy_datas)}")
# Out:
# 🚀 Démarrage du processus de collecte des données...
#
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : southwest pass, la
# 🆔 Station ID : BURL1
# ✅ Coordonnées extraites : Latitude = 28.91N, Longitude = 89.43W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 13.4
# 💨 Anemometer Height : 38
# 🌤️ Air Temp Height : 13.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=BURL1
# ✅ Parsing terminé !
#
# 📊 station_zone : southwest pass, la
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : grays reef
# 🆔 Station ID : 41008
# ✅ Coordonnées extraites : Latitude = 31.40N, Longitude = 80.87W
# 🌊 Water Depth : 16 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=41008
# ✅ Parsing terminé !
#
# 📊 station_zone : grays reef
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : five fingers, ak
# 🆔 Station ID : FFIA2
# ✅ Coordonnées extraites : Latitude = 57.27N, Longitude = 133.63W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 21.3
# 💨 Anemometer Height : 22
# 🌤️ Air Temp Height : 4.3
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=FFIA2
# ✅ Parsing terminé !
#
# 📊 station_zone : five fingers, ak
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : ne st martin
# 🆔 Station ID : 41044
# ✅ Coordonnées extraites : Latitude = 21.58N, Longitude = 58.63W
# 🌊 Water Depth : 5419 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=41044
# ✅ Parsing terminé !
#
# 📊 station_zone : ne st martin
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
# ⚠️ Erreur collecte marine KTNF1: Error accessing https://www.ndbc.noaa.gov/data/realtime2/KTNF1.txt
# Server Error ( 404: Not Found)
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : south bermuda
# 🆔 Station ID : 41049
# ✅ Coordonnées extraites : Latitude = 27.50N, Longitude = 62.27W
# 🌊 Water Depth : 5480 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=41049
# ✅ Parsing terminé !
#
# 📊 station_zone : south bermuda
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : mid gulf
# 🆔 Station ID : 42001
# ✅ Coordonnées extraites : Latitude = 25.93N, Longitude = 89.66W
# 🌊 Water Depth : 3200 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42001
# ✅ Parsing terminé !
#
# 📊 station_zone : mid gulf
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : long key, fl
# 🆔 Station ID : LONF1
# ✅ Coordonnées extraites : Latitude = 24.84N, Longitude = 80.86W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 5.03
# 💨 Anemometer Height : 6.34
# 🌤️ Air Temp Height : 6.1
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=LONF1
# ✅ Parsing terminé !
#
# 📊 station_zone : long key, fl
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : mt. desert rock, me
# 🆔 Station ID : MDRM1
# ✅ Coordonnées extraites : Latitude = 43.97N, Longitude = 68.13W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 16.5
# 💨 Anemometer Height : 22.6
# 🌤️ Air Temp Height : 15.2
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=MDRM1
# ✅ Parsing terminé !
#
# 📊 station_zone : mt. desert rock, me
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : west gulf
# 🆔 Station ID : 42002
# ✅ Coordonnées extraites : Latitude = 25.95N, Longitude = 93.78W
# 🌊 Water Depth : 3208 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42002
# ✅ Parsing terminé !
#
# 📊 station_zone : west gulf
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : middle rock light, ak
# 🆔 Station ID : MRKA2
# ✅ Coordonnées extraites : Latitude = 61.08N, Longitude = 146.66W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 10.9
# 💨 Anemometer Height : 15.9
# 🌤️ Air Temp Height : 15.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=MRKA2
# ✅ Parsing terminé !
#
# 📊 station_zone : middle rock light, ak
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : orange beach
# 🆔 Station ID : 42012
# ✅ Coordonnées extraites : Latitude = 30.06N, Longitude = 87.55W
# 🌊 Water Depth : 23.5 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42012
# ✅ Parsing terminé !
#
# 📊 station_zone : orange beach
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : potato point, ak
# 🆔 Station ID : POTA2
# ✅ Coordonnées extraites : Latitude = 61.06N, Longitude = 146.70W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 8.5
# 💨 Anemometer Height : 10
# 🌤️ Air Temp Height : 9.1
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=POTA2
# ✅ Parsing terminé !
#
# 📊 station_zone : potato point, ak
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : west tampa
# 🆔 Station ID : 42036
# ✅ Coordonnées extraites : Latitude = 28.50N, Longitude = 84.50W
# 🌊 Water Depth : 53.3 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42036
# ✅ Parsing terminé !
#
# 📊 station_zone : west tampa
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : sand key, fl
# 🆔 Station ID : SANF1
# ✅ Coordonnées extraites : Latitude = 24.46N, Longitude = 81.88W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 13.6
# 💨 Anemometer Height : 14.8
# 🌤️ Air Temp Height : 14.6
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=SANF1
# ✅ Parsing terminé !
#
# 📊 station_zone : sand key, fl
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : yucatan basin
# 🆔 Station ID : 42056
# ✅ Coordonnées extraites : Latitude = 19.82N, Longitude = 84.98W
# 🌊 Water Depth : 4578 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42056
# ✅ Parsing terminé !
#
# 📊 station_zone : yucatan basin
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : south bass island, oh
# 🆔 Station ID : SBIO1
# ✅ Coordonnées extraites : Latitude = 41.63N, Longitude = 82.84W
# 🌊 Water Depth : N/A
# 🌡️ Sea Temp Depth : None
# 🌬️ Barometer Elevation (m): 178.4
# 💨 Anemometer Height : 24.3
# 🌤️ Air Temp Height : 23.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=SBIO1
# ✅ Parsing terminé !
#
# 📊 station_zone : south bass island, oh
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : central caribbean
# 🆔 Station ID : 42058
# ✅ Coordonnées extraites : Latitude = 14.51N, Longitude = 75.15W
# 🌊 Water Depth : 4136 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=42058
# ✅ Parsing terminé !
#
# 📊 station_zone : central caribbean
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
# ⚠️ Erreur collecte marine SMKF1: Error accessing https://www.ndbc.noaa.gov/data/realtime2/SMKF1.txt
# Server Error ( 404: Not Found)
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : portland
# 🆔 Station ID : 44007
# ✅ Coordonnées extraites : Latitude = 43.52N, Longitude = 70.14W
# 🌊 Water Depth : 49 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44007
# ✅ Parsing terminé !
#
# 📊 station_zone : portland
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : nantucket sound
# 🆔 Station ID : 44020
# ✅ Coordonnées extraites : Latitude = 41.50N, Longitude = 70.28W
# 🌊 Water Depth : 16.5 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44020
# ✅ Parsing terminé !
#
# 📊 station_zone : nantucket sound
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : long island
# 🆔 Station ID : 44025
# ✅ Coordonnées extraites : Latitude = 40.26N, Longitude = 73.17W
# 🌊 Water Depth : 40.2 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44025
# ✅ Parsing terminé !
#
# 📊 station_zone : long island
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : jonesport, me
# 🆔 Station ID : 44027
# ✅ Coordonnées extraites : Latitude = 44.28N, Longitude = 67.30W
# 🌊 Water Depth : 188 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44027
# ✅ Parsing terminé !
#
# 📊 station_zone : jonesport, me
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : new york harbor entrance
# 🆔 Station ID : 44065
# ✅ Coordonnées extraites : Latitude = 40.37N, Longitude = 73.70W
# 🌊 Water Depth : 26 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=44065
# ✅ Parsing terminé !
#
# 📊 station_zone : new york harbor entrance
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : western gulf of alaska
# 🆔 Station ID : 46001
# ✅ Coordonnées extraites : Latitude = 56.30N, Longitude = 148.03W
# 🌊 Water Depth : 4123 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46001
# ✅ Parsing terminé !
#
# 📊 station_zone : western gulf of alaska
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : southeast papa
# 🆔 Station ID : 46006
# ✅ Coordonnées extraites : Latitude = 40.76N, Longitude = 137.38W
# 🌊 Water Depth : 4347 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46006
# ✅ Parsing terminé !
#
# 📊 station_zone : southeast papa
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : pt arena
# 🆔 Station ID : 46014
# ✅ Coordonnées extraites : Latitude = 39.23N, Longitude = 123.98W
# 🌊 Water Depth : 335 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46014
# ✅ Parsing terminé !
#
# 📊 station_zone : pt arena
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : eel river
# 🆔 Station ID : 46022
# ✅ Coordonnées extraites : Latitude = 40.72N, Longitude = 124.54W
# 🌊 Water Depth : 456 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 3.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46022
# ✅ Parsing terminé !
#
# 📊 station_zone : eel river
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : santa monica basin
# 🆔 Station ID : 46025
# ✅ Coordonnées extraites : Latitude = 33.76N, Longitude = 119.05W
# 🌊 Water Depth : 890 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46025
# ✅ Parsing terminé !
#
# 📊 station_zone : santa monica basin
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : st georges
# 🆔 Station ID : 46027
# ✅ Coordonnées extraites : Latitude = 41.84N, Longitude = 124.38W
# 🌊 Water Depth : 60 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46027
# ✅ Parsing terminé !
#
# 📊 station_zone : st georges
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : columbia river bar
# 🆔 Station ID : 46029
# ✅ Coordonnées extraites : Latitude = 46.16N, Longitude = 124.49W
# 🌊 Water Depth : 131 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46029
# ✅ Parsing terminé !
#
# 📊 station_zone : columbia river bar
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : east santa barbara
# 🆔 Station ID : 46053
# ✅ Coordonnées extraites : Latitude = 34.24N, Longitude = 119.84W
# 🌊 Water Depth : 405 m
# 🌡️ Sea Temp Depth : 1.1
# 🌬️ Barometer Elevation (m): 1.8
# 💨 Anemometer Height : 3.2
# 🌤️ Air Temp Height : 2.8
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46053
# ✅ Parsing terminé !
#
# 📊 station_zone : east santa barbara
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : south santa rosa
# 🆔 Station ID : 46069
# ✅ Coordonnées extraites : Latitude = 33.68N, Longitude = 120.21W
# 🌊 Water Depth : 977.8 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46069
# ✅ Parsing terminé !
#
# 📊 station_zone : south santa rosa
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : western aleutians
# 🆔 Station ID : 46071
# ✅ Coordonnées extraites : Latitude = 51.04N, Longitude = 179.76E
# 🌊 Water Depth : 3967 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46071
# ✅ Parsing terminé !
#
# 📊 station_zone : western aleutians
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : central aleutians 230 nm sw dutch harbor
# 🆔 Station ID : 46072
# ✅ Coordonnées extraites : Latitude = 51.65N, Longitude = 172.15W
# 🌊 Water Depth : 3589 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46072
# ✅ Parsing terminé !
#
# 📊 station_zone : central aleutians 230 nm sw dutch harbor
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : albatross bank
# 🆔 Station ID : 46078
# ✅ Coordonnées extraites : Latitude = 55.56N, Longitude = 152.60W
# 🌊 Water Depth : 5361 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46078
# ✅ Parsing terminé !
#
# 📊 station_zone : albatross bank
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : cape edgecumbe
# 🆔 Station ID : 46084
# ✅ Coordonnées extraites : Latitude = 56.61N, Longitude = 136.04W
# 🌊 Water Depth : 1149 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46084
# ✅ Parsing terminé !
#
# 📊 station_zone : cape edgecumbe
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : san clemente basin
# 🆔 Station ID : 46086
# ✅ Coordonnées extraites : Latitude = 32.50N, Longitude = 118.05W
# 🌊 Water Depth : 1844.7 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46086
# ✅ Parsing terminé !
#
# 📊 station_zone : san clemente basin
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : neah bay
# 🆔 Station ID : 46087
# ✅ Coordonnées extraites : Latitude = 48.49N, Longitude = 124.73W
# 🌊 Water Depth : 262.4 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46087
# ✅ Parsing terminé !
#
# 📊 station_zone : neah bay
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : new dungeness
# 🆔 Station ID : 46088
# ✅ Coordonnées extraites : Latitude = 48.33N, Longitude = 123.18W
# 🌊 Water Depth : 115.5 m
# 🌡️ Sea Temp Depth : 2
# 🌬️ Barometer Elevation (m): 2.4
# 💨 Anemometer Height : 3.8
# 🌤️ Air Temp Height : 3.4
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=46088
# ✅ Parsing terminé !
#
# 📊 station_zone : new dungeness
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : northern hawaii one
# 🆔 Station ID : 51000
# ✅ Coordonnées extraites : Latitude = 23.53N, Longitude = 153.79W
# 🌊 Water Depth : 4762 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=51000
# ✅ Parsing terminé !
#
# 📊 station_zone : northern hawaii one
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : northwestern hawaii one
# 🆔 Station ID : 51001
# ✅ Coordonnées extraites : Latitude = 24.48N, Longitude = 162.03W
# 🌊 Water Depth : 4895 m
# 🌡️ Sea Temp Depth : 1.1
# 🌬️ Barometer Elevation (m): 1.8
# 💨 Anemometer Height : 3.2
# 🌤️ Air Temp Height : 2.8
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=51001
# ✅ Parsing terminé !
#
# 📊 station_zone : northwestern hawaii one
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 🔍 Début du parsing de la bouée...
# 🌍 Zone de la station : southwest hawaii
# 🆔 Station ID : 51002
# ✅ Coordonnées extraites : Latitude = 17.07N, Longitude = 157.75W
# 🌊 Water Depth : 4979 m
# 🌡️ Sea Temp Depth : 1.5
# 🌬️ Barometer Elevation (m): 2.7
# 💨 Anemometer Height : 4.1
# 🌤️ Air Temp Height : 3.7
# 🔗 URL de la bouée : https://www.ndbc.noaa.gov/station_page.php?station=51002
# ✅ Parsing terminé !
#
# 📊 station_zone : southwest hawaii
# 🔄 Colonne 'date' renommée en 'Datetime'
# ✅ Colonnes renommées : {'date': 'Datetime'}
#
# 📝 Résumé final :
# 🌊 Marine - Collecte ✅ 41 ❌ 2
# ⛅ Météo - Collecte ✅ 41 ❌ 0
#
# 📊 Nombre de bouées avec des données valides : 41

# %%
display_buoys_missing_df_counts(buoy_datas)
# Out:
# 🌊 Nombre de bouées sans données 'Marine' : 0/41
#
# ☁️ Nombre de bouées sans données 'Meteo' : 0/41

# %% [markdown]
# # Data Enrichment with MetaDatas

# %%
# Liste des colonnes à ne pas inclure dans l'ajout
list_not_include = ['lon_buoy', "lat_buoy", "url"]

# Parcours des bouées
for buoy_id, value in buoy_datas.items():
    print(f"\n🔍 Traitement de la Station ID: {buoy_id}")

    marine_df = buoy_datas[buoy_id]["Marine"]
    meteo_df = buoy_datas[buoy_id]["Meteo"]

    try:
        # Récupérer les métadonnées de la station
        buoy_metadata = get_station_metadata(buoy_id)
        parsed_data = parse_buoy_json(buoy_metadata)

        # Mise à jour du dictionnaire avec les métadonnées
        data = buoy_datas[buoy_id]
        data.update(parsed_data)
        
        # Si marine_df est un DataFrame Pandas, on le convertit en Dask
        if marine_df is not None:
            # Vérifier si le DataFrame est valide
            if not marine_df.empty:
                marine_df = dd.from_pandas(marine_df, npartitions=4)
                marine_df["Station ID"] = str(buoy_id)  # Ajout de la station ID

                # Ajouter les métadonnées
                for key, value in parsed_data.items():
                    if key not in list_not_include:
                        marine_df[key] = value
                        print(f"✅ Colonne '{key}' ajoutée au DataFrame de la station {buoy_id}")

                # Mise à jour de la bouée avec le DataFrame Dask
                buoy_datas[buoy_id]["Marine"] = marine_df

    except Exception as e:
        print(f"❌ Erreur pour la station {buoy_id}: {e}")

# Vérification de l'ajout des colonnes en prenant un id au hasard
station_id = random.choice(list(buoy_datas.keys()))
marine_df = buoy_datas[station_id]["Marine"]

if marine_df is not None:
    print("\nColonnes ajoutées au DataFrame de la station", station_id)
    print(marine_df.columns.to_list())  # Affiche les colonnes sans faire de .compute()
# Out:
# 🔍 Traitement de la Station ID: BURL1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\_expr.py:768, in Expr.__getattr__(self, key)
#     767 try:
# --> 768     return object.__getattribute__(self, key)
#     769 except AttributeError as err:
#
# AttributeError: 'Assign' object has no attribute 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\_expr.py:768, in Expr.__getattr__(self, key)
#     767 try:
# --> 768     return object.__getattribute__(self, key)
#     769 except AttributeError as err:
#
# File C:\Program Files\Python313\Lib\functools.py:1042, in cached_property.__get__(self, instance, owner)
#    1041 if val is _NOT_FOUND:
# -> 1042     val = self.func(instance)
#    1043     try:
#
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\dataframe\dask_expr\io\io.py:427, in FromPandas._meta(self)
#     426 if self.pyarrow_strings_enabled:
# --> 427     meta = make_meta(to_pyarrow_string(self.frame.head(1)))
#     428 else:
#
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\dataframe\dask_expr\_expr.py:152, in Expr.__getattr__(self, key)
#     151 try:
# --> 152     return super().__getattr__(key)
#     153 except AttributeError:
#
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\_expr.py:786, in Expr.__getattr__(self, key)
#     784     return self.operands[idx]
# --> 786 raise AttributeError(
#     787     f"{err}\n\n"
#     788     "This often means that you are attempting to use an unsupported "
#     789     f"API function.."
#     790 )
#
# AttributeError: 'Assign' object has no attribute 'head'
#
# This often means that you are attempting to use an unsupported API function..
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 15
#      12 # Vérifier si les DataFrames Pandas sont valides avant la conversion
#      13 if buoy_datas[buoy_id]["Marine"] is not None and len(buoy_datas[buoy_id]["Marine"].columns) > 0:
#      14     # Conversion en Dask DataFrame (sans l'argument 'meta')
# ---> 15     marine_df = dd.from_pandas(buoy_datas[buoy_id]["Marine"], npartitions=4)
#      16     buoy_datas[buoy_id]["Marine"] = marine_df
#      17     print("Conversion en Dask pour Marine effectuée")
#
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\dataframe\dask_expr\_collection.py:4910, in from_pandas(data, npartitions, sort, chunksize)
#    4904     raise TypeError(
#    4905         "Please provide chunksize as an int, or possibly as None if you specify npartitions."
#    4906     )
#    4908 from dask.dataframe.dask_expr.io.io import FromPandas
# -> 4910 return new_collection(
#    4911     FromPandas(
#    4912         _BackendData(data.copy()),
#    4913         npartitions=npartitions,
#    4914         sort=sort,
#    4915         chunksize=chunksize,
#    4916         pyarrow_strings_enabled=pyarrow_strings_enabled(),
#    4917     )
#    4918 )
#
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\_collections.py:8, in new_collection(expr)
#       6 def new_collection(expr):
#       7     """Create new collection from an expr"""
# ----> 8     meta = expr._meta
#       9     expr._name  # Ensure backend is imported
#      10     return get_collection_type(meta)(expr)
#
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\dataframe\dask_expr\_expr.py:152, in Expr.__getattr__(self, key)
#     150 def __getattr__(self, key):
#     151     try:
# --> 152         return super().__getattr__(key)
#     153     except AttributeError:
#     155         if is_dataframe_like(self._meta) and key in self._meta.columns:
#
# File c:\Users\f.gionnane\Documents\Ocean ETL Data Analysis\env\Lib\site-packages\dask\_expr.py:773, in Expr.__getattr__(self, key)
#     769 except AttributeError as err:
#     770     if key.startswith("_meta"):
#     771         # Avoid a recursive loop if/when `self._meta*`
#     772         # produces an `AttributeError`
# --> 773         raise RuntimeError(
#     774             f"Failed to generate metadata for {self}. "
#     775             "This operation may not be supported by the current backend."
#     776         )
#     778     # Allow operands to be accessed as attributes
#     779     # as long as the keys are not already reserved
#     780     # by existing methods/properties
#     781     _parameters = type(self)._parameters
#
# RuntimeError: Failed to generate metadata for df. This operation may not be supported by the current backend.

# %%
display_row_values(df_marine)

# %%
display(df_marine.columns)
display(df_meteo.columns)

# %% [markdown]
# # Handle Null Values

# %%
important_columns_oceanography = [
    'wind_direction',             
    'wind_speed',                 
    'wave_height',                   
    'pressure',                   
    'air_temperature',            
    'water_temperature',          
    'Datetime',
    'Lat',
    'Lon'                 
]

important_columns_meteorology = [
    'temperature_2m',             
    'relative_humidity_2m',       
    'dew_point_2m',               
    'precipitation',              
    'pressure_msl',               
    'cloud_cover',                
    'wind_speed_10m',             
    'Datetime'
]

stations_depart = len(buoy_datas)
ignored_buoys = {}  # Dictionary to track ignored buoys and their reasons

for station_id, data in buoy_datas.items():
    print(f"\n🔄 Nettoyage des données pour la station {station_id}")

    marine_df = data.get("Marine")
    meteo_df = data.get("Meteo")

    if marine_df is None or meteo_df is None:
        ignored_buoys[station_id] = "Marine DataFrame ou Meteo DataFrame manquant(e)"
        print(f"⚠️ Station {station_id} ignorée: Marine DataFrame ou Meteo DataFrame manquant(e)")
        continue

    try:
        # Convertir les pandas DataFrames en Dask DataFrames
        marine_df = dd.from_pandas(marine_df, npartitions=4)
        meteo_df = dd.from_pandas(meteo_df, npartitions=4)

        # Nettoyage des DataFrames
        cleaned_marine_df = handle_null_values(marine_df)
        cleaned_meteo_df = handle_null_values(meteo_df)

        # Vérification des colonnes importantes après nettoyage
        marine_columns_ok = all(col in cleaned_marine_df.columns for col in important_columns_oceanography)
        meteo_columns_ok = all(col in cleaned_meteo_df.columns for col in important_columns_meteorology)

        # Track which columns are missing
        missing_marine_columns = [col for col in important_columns_oceanography if col not in cleaned_marine_df.columns]
        missing_meteo_columns = [col for col in important_columns_meteorology if col not in cleaned_meteo_df.columns]

        if missing_marine_columns or missing_meteo_columns:
            ignored_buoys[station_id] = f"Colonnes manquantes: Marine: {missing_marine_columns}, Meteo: {missing_meteo_columns}"
            print(f"⚠️ Station {station_id} ignorée: Colonnes manquantes - Marine: {missing_marine_columns}, Meteo: {missing_meteo_columns}")
            continue

        # Ajouter le DataFrame nettoyé au dictionnaire des résultats
        buoy_datas[station_id]['Cleaned Marine'] = cleaned_marine_df
        buoy_datas[station_id]['Cleaned Meteo'] = cleaned_meteo_df
        print(f"✅ Nettoyage réussi pour la station {station_id} ({cleaned_marine_df.shape[0].compute()} lignes)")

    except Exception as e:
        ignored_buoys[station_id] = f"Erreur lors du nettoyage: {e}"
        print(f"❌ Erreur lors du nettoyage pour {station_id}: {e}")

# 🔥 Suppression des stations ignorées du dictionnaire principal
for station_id in ignored_buoys:
    buoy_datas.pop(station_id, None)

len_cleaned_data = len([data for data in buoy_datas.values() if 'Cleaned Marine' in data and 'Cleaned Meteo' in data])

# Résumé final du nettoyage
print("\n📊 RÉSUMÉ DU NETTOYAGE:")
print(f"📌 Stations au départ : {stations_depart}")
print(f"✅ Stations nettoyées : {len_cleaned_data}")
print(f"🏁 Stations restantes après filtrage :")

for station_id, reason in ignored_buoys.items():
    print(f"🛑 Station {station_id} ignorée: {reason}")

print(f"\n🧹 Clés restantes dans buoy_datas après purge : {len(buoy_datas)} (attendu : {len_cleaned_data})")
